# %% [markdown]
# ## Hybrid Models
#
# #### LSTM (Long Short-Term Memory) and Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('apple_stock_data.csv')

# %%
data.head()
# Out:
#                         Date   Adj Close       Close        High         Low  \
# 0  2023-11-02 00:00:00+00:00  176.665985  177.570007  177.779999  175.460007
# 1  2023-11-03 00:00:00+00:00  175.750671  176.649994  176.820007  173.350006
# 2  2023-11-06 00:00:00+00:00  178.317520  179.229996  179.429993  176.210007
# 3  2023-11-07 00:00:00+00:00  180.894333  181.820007  182.440002  178.970001
# 4  2023-11-08 00:00:00+00:00  181.958893  182.889999  183.449997  181.589996
#
#          Open    Volume
# 0  175.520004  77334800
# 1  174.240005  79763700
# 2  176.380005  63841300
# 3  179.179993  70530000
# 4  182.350006  49340300

# %%
# Converting the date column to a datetime type
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)

# %%
data.head()
# Out:
#                             Adj Close       Close        High         Low  \
# Date
# 2023-11-02 00:00:00+00:00  176.665985  177.570007  177.779999  175.460007
# 2023-11-03 00:00:00+00:00  175.750671  176.649994  176.820007  173.350006
# 2023-11-06 00:00:00+00:00  178.317520  179.229996  179.429993  176.210007
# 2023-11-07 00:00:00+00:00  180.894333  181.820007  182.440002  178.970001
# 2023-11-08 00:00:00+00:00  181.958893  182.889999  183.449997  181.589996
#
#                                  Open    Volume
# Date
# 2023-11-02 00:00:00+00:00  175.520004  77334800
# 2023-11-03 00:00:00+00:00  174.240005  79763700
# 2023-11-06 00:00:00+00:00  176.380005  63841300
# 2023-11-07 00:00:00+00:00  179.179993  70530000
# 2023-11-08 00:00:00+00:00  182.350006  49340300

# %%
plt.figure(figsize=(20, 10))
plt.plot(data.index, data['Close'], label='Close Price')
plt.plot(data.index, data['Adj Close'], label='Adjusted Close Price')
plt.plot(data.index, data['High'], label='High Price')
plt.plot(data.index, data['Low'], label='Low Price')
plt.plot(data.index, data['Open'], label='Open Price')
plt.legend()
plt.xlabel('Close Price')
plt.ylabel('Date')
plt.show()

# %% [markdown]
# ##### Focusing on the Close price

# %%
data = data[['Close']]

# %%
data
# Out:
#                                 Close
# Date
# 2023-11-02 00:00:00+00:00  177.570007
# 2023-11-03 00:00:00+00:00  176.649994
# 2023-11-06 00:00:00+00:00  179.229996
# 2023-11-07 00:00:00+00:00  181.820007
# 2023-11-08 00:00:00+00:00  182.889999
# ...                               ...
# 2024-10-28 00:00:00+00:00  233.399994
# 2024-10-29 00:00:00+00:00  233.669998
# 2024-10-30 00:00:00+00:00  230.100006
# 2024-10-31 00:00:00+00:00  225.910004
# 2024-11-01 00:00:00+00:00  222.910004
#
# [252 rows x 1 columns]

# %%
plt.figure(figsize=(12, 6))
plt.plot(data.index, data['Close'], label='Actual')
plt.xlabel('Close Price')
plt.ylabel('Date')
plt.show()

# %%
# Scaling the Close price data between 0 and 1 using MinMaxScaler to ensure compatibility with the LSTM model
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
data['Close'] = scaler.fit_transform(data[['Close']])

# %%
# Preparing the data for LSTM by creating sequences of a defined length (60 days) to predict the next day’s price
def create_sequences(data, sequence_length=60):
    X, y = [], []
    for i in range(len(data) - sequence_length):
        X.append(data[i:i+sequence_length])
        y.append(data[i+sequence_length])
    return np.array(X), np.array(y)

# %%
sequence_length = 60
X, y = create_sequences(data['Close'].values, sequence_length)

# %%
# Splitting the sequences into training and test sets (80% training, 20% testing)
train_size = int(len(X) * 0.8)

X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %% [markdown]
# ##### LSTM Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

lstm_model = Sequential()
lstm_model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
lstm_model.add(LSTM(units=50))
lstm_model.add(Dense(units=1))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
lstm_model.compile(optimizer='adam', loss='mean_squared_error')
lstm_model.fit(X_train, y_train, epochs=20, batch_size=32)
# Out:
# Epoch 1/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1464
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0282
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0209
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0189
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0160
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0116
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0125
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0092
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0111
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0092
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0098
# Epoch 12/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0092
# Epoch 13/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0088
# Epoch 14/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0083
# Epoch 15/20
# ...

# %% [markdown]
# ##### Linear Model

# %%
# Generating lagged features for Linear Regression using the past 3 days as predictors
data['Lag_1'] = data['Close'].shift(1)
data['Lag_2'] = data['Close'].shift(2)
data['Lag_3'] = data['Close'].shift(3)

# %%
data.head()
# Out:
#                               Close     Lag_1     Lag_2     Lag_3
# Date
# 2023-11-02 00:00:00+00:00  0.175853       NaN       NaN       NaN
# 2023-11-03 00:00:00+00:00  0.162983  0.175853       NaN       NaN
# 2023-11-06 00:00:00+00:00  0.199077  0.162983  0.175853       NaN
# 2023-11-07 00:00:00+00:00  0.235311  0.199077  0.162983  0.175853
# 2023-11-08 00:00:00+00:00  0.250280  0.235311  0.199077  0.162983

# %%
data = data.dropna()

# %%
data.head()
# Out:
#                               Close     Lag_1     Lag_2     Lag_3
# Date
# 2023-11-07 00:00:00+00:00  0.235311  0.199077  0.162983  0.175853
# 2023-11-08 00:00:00+00:00  0.250280  0.235311  0.199077  0.162983
# 2023-11-09 00:00:00+00:00  0.243565  0.250280  0.235311  0.199077
# 2023-11-10 00:00:00+00:00  0.299384  0.243565  0.250280  0.235311
# 2023-11-13 00:00:00+00:00  0.277001  0.299384  0.243565  0.250280

# %%
X_lin = data[['Lag_1', 'Lag_2', 'Lag_3']]
y_lin = data['Close']

X_train_lin, X_test_lin = X_lin[:train_size], X_lin[train_size:]
y_train_lin, y_test_lin = y_lin[:train_size], y_lin[train_size:]

# %%
from sklearn.linear_model import LinearRegression

lin_model = LinearRegression()
lin_model.fit(X_train_lin, y_train_lin)
# Out:
# LinearRegression()

# %%
# Making predictions using LSTM
X_test_lstm = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

lstm_predictions = lstm_model.predict(X_test_lstm)
lstm_predictions = scaler.inverse_transform(lstm_predictions)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step

# %%
# Making predictions using Linear Regression
lin_predictions = lin_model.predict(X_test_lin)
lin_predictions = scaler.inverse_transform(lin_predictions.reshape(-1, 1))

# %% [markdown]
# ##### Predicting using the Hybrid Model

# %%
# Predicting the Next 10 Days using LSTM
lstm_future_predictions = []
last_sequence = X[-1].reshape(1, sequence_length, 1)
for _ in range(10):
    lstm_pred = lstm_model.predict(last_sequence)[0, 0]
    lstm_future_predictions.append(lstm_pred)
    lstm_pred_reshaped = np.array([[lstm_pred]]).reshape(1, 1, 1)
    last_sequence = np.append(last_sequence[:, 1:, :], lstm_pred_reshaped, axis=1)
lstm_future_predictions = scaler.inverse_transform(np.array(lstm_future_predictions).reshape(-1, 1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
# Predicting the Next 10 Days using Linear Regression
recent_data = data['Close'].values[-3:]
lin_future_predictions = []
for _ in range(10):
    lin_pred = lin_model.predict(recent_data.reshape(1, -1))[0]
    lin_future_predictions.append(lin_pred)
    recent_data = np.append(recent_data[1:], lin_pred)
lin_future_predictions = scaler.inverse_transform(np.array(lin_future_predictions).reshape(-1, 1))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ...

# %%
# Combining the predictive power of both models to make predictions for the next 10 days
hybrid_future_predictions = (0.7 * lstm_future_predictions) + (0.3 * lin_future_predictions)  # weighted average

# %%
# Final DF
future_dates = pd.date_range(start=data.index[-1] + pd.Timedelta(days=1), periods=10)
predictions_df = pd.DataFrame({
    'Date': future_dates,
    'LSTM Predictions': lstm_future_predictions.flatten(),
    'Linear Regression Predictions': lin_future_predictions.flatten(),
    'Hybrid Model Predictions': hybrid_future_predictions.flatten()
})
print(predictions_df)
# Out:
#                        Date  LSTM Predictions  Linear Regression Predictions  \
# 0 2024-11-02 00:00:00+00:00        231.480240                     230.355192
# 1 2024-11-03 00:00:00+00:00        231.156372                     225.707291
# 2 2024-11-04 00:00:00+00:00        230.872025                     222.703426
# 3 2024-11-05 00:00:00+00:00        230.614456                     230.631535
# 4 2024-11-06 00:00:00+00:00        230.374207                     225.486380
# 5 2024-11-07 00:00:00+00:00        230.145065                     222.494588
# 6 2024-11-08 00:00:00+00:00        229.922913                     230.930195
# 7 2024-11-09 00:00:00+00:00        229.705093                     225.245599
# 8 2024-11-10 00:00:00+00:00        229.489990                     222.284007
# 9 2024-11-11 00:00:00+00:00        229.276566                     231.252375
#
#    Hybrid Model Predictions
# 0                231.142721
# 1                229.521651
# 2                228.421440
# ...

# %%
plt.figure(figsize=(20, 10))

plt.plot(predictions_df['Date'], predictions_df['LSTM Predictions'], label='LSTM Predictions')
plt.plot(predictions_df['Date'], predictions_df['Linear Regression Predictions'], label='Linear Regression Predictions')
plt.plot(predictions_df['Date'], predictions_df['Hybrid Model Predictions'], label='Hybrid Model Predictions')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Stock Price Prediction')
plt.legend()
plt.show()
